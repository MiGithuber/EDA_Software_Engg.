# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Research software/23111-0001_$F.xlsx")
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#   Hospitals, beds, patients: Germany, years Unnamed: 1 Unnamed: 2  \
# 0                   Basic data on hospitals        NaN        NaN
# 1                                   Germany        NaN        NaN
# 2                                      Year  Hospitals       Beds
# 3                                       NaN     number     number
# 4                                      1991       2411     665565
#
#                      Unnamed: 3 Unnamed: 4                        Unnamed: 5  \
# 0                           NaN        NaN                               NaN
# 1                           NaN        NaN                               NaN
# 2  Beds per 100 000 inhabitants   Patients  Patients per 100 000 inhabitants
# 3                        number     number                            number
# 4                           832   14576613                             18224
#
#                  Unnamed: 6              Unnamed: 7  \
# ...

# %%
df.shape
# Out:
# (38, 9)

# %%
df=df.dropna()

# %%
df.head(5)
# Out:
#   Hospitals, beds, patients: Germany, years Unnamed: 1 Unnamed: 2  \
# 2                                      Year  Hospitals       Beds
# 4                                      1991       2411     665565
# 5                                      1992       2381     646995
# 6                                      1993       2354     628658
# 7                                      1994       2337     618176
#
#                      Unnamed: 3 Unnamed: 4                        Unnamed: 5  \
# 2  Beds per 100 000 inhabitants   Patients  Patients per 100 000 inhabitants
# 4                           832   14576613                             18224
# 5                           803   14974845                             18581
# 6                           774   15191174                             18713
# 7                           759   15497702                             19034
#
#                  Unnamed: 6              Unnamed: 7  \
# ...

# %%
headers =  ["Year", "Hospitals", "Beds", "Beds per 1lakh inhabitants","Patients","Patients per 1lakh inhabitants","Occupancy / billing days","Average length of stay","Average occupancy of hospital beds"]
df.columns = headers

# %%
df.head()
# Out:
#    Year  Hospitals    Beds    Beds per 1lakh inhabitants  Patients  \
# 2  Year  Hospitals    Beds  Beds per 100 000 inhabitants  Patients
# 4  1991       2411  665565                           832  14576613
# 5  1992       2381  646995                           803  14974845
# 6  1993       2354  628658                           774  15191174
# 7  1994       2337  618176                           759  15497702
#
#      Patients per 1lakh inhabitants  Occupancy / billing days  \
# 2  Patients per 100 000 inhabitants  Occupancy / billing days
# 4                             18224                    204204
# 5                             18581                    198769
# 6                             18713                    190741
# 7                             19034                    186049
#
#    Average length of stay  Average occupancy of hospital beds
# 2  Average length of stay  Average occupancy of hospital beds
# 4                      14                                84.1
# ...

# %%
df=df.drop(2,axis=0)

# %%
df.head()
# Out:
#    Year Hospitals    Beds Beds per 1lakh inhabitants  Patients  \
# 4  1991      2411  665565                        832  14576613
# 5  1992      2381  646995                        803  14974845
# 6  1993      2354  628658                        774  15191174
# 7  1994      2337  618176                        759  15497702
# 8  1995      2325  609123                        746  15931168
#
#   Patients per 1lakh inhabitants Occupancy / billing days  \
# 4                          18224                   204204
# 5                          18581                   198769
# 6                          18713                   190741
# 7                          19034                   186049
# 8                          19509                   182627
#
#   Average length of stay Average occupancy of hospital beds
# 4                     14                               84.1
# 5                   13.2                               83.9
# ...

# %%
df=df.reset_index()

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.shape
# Out:
# (31, 9)

# %%
df.head()
# Out:
#    Year Hospitals    Beds Beds per 1lakh inhabitants  Patients  \
# 0  1991      2411  665565                        832  14576613
# 1  1992      2381  646995                        803  14974845
# 2  1993      2354  628658                        774  15191174
# 3  1994      2337  618176                        759  15497702
# 4  1995      2325  609123                        746  15931168
#
#   Patients per 1lakh inhabitants Occupancy / billing days  \
# 0                          18224                   204204
# 1                          18581                   198769
# 2                          18713                   190741
# 3                          19034                   186049
# 4                          19509                   182627
#
#   Average length of stay Average occupancy of hospital beds
# 0                     14                               84.1
# 1                   13.2                               83.9
# ...

# %%
df.isnull().sum()
# Out:
# Year                                  0
# Hospitals                             0
# Beds                                  0
# Beds per 1lakh inhabitants            0
# Patients                              0
# Patients per 1lakh inhabitants        0
# Occupancy / billing days              0
# Average length of stay                0
# Average occupancy of hospital beds    0
# dtype: int64

# %%
df.std()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7080\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Hospitals                             1.579676e+02
# Beds                                  5.164983e+04
# Beds per 1lakh inhabitants            6.678494e+01
# Patients                              1.387142e+06
# Patients per 1lakh inhabitants        1.662669e+03
# Occupancy / billing days              2.154546e+04
# Average length of stay                1.922996e+00
# Average occupancy of hospital beds    3.854432e+00
# dtype: float64

# %%
df.dtypes
# Out:
# Year                                  object
# Hospitals                             object
# Beds                                  object
# Beds per 1lakh inhabitants            object
# Patients                              object
# Patients per 1lakh inhabitants        object
# Occupancy / billing days              object
# Average length of stay                object
# Average occupancy of hospital beds    object
# dtype: object

# %% [markdown]
# ## We have to convert the data type to int as the values are in the numerical format.

# %%
headers =  ["Year", "Hospitals", "Beds", "Beds per 1lakh inhabitants","Patients","Patients per 1lakh inhabitants","Occupancy / billing days","Average length of stay","Average occupancy of hospital beds"]
for i in headers:
    df[i] = df[i].astype(int)

# %%
df.dtypes
# Out:
# Year                                  int32
# Hospitals                             int32
# Beds                                  int32
# Beds per 1lakh inhabitants            int32
# Patients                              int32
# Patients per 1lakh inhabitants        int32
# Occupancy / billing days              int32
# Average length of stay                int32
# Average occupancy of hospital beds    int32
# dtype: object

# %%
Beds=df['Beds'].mean()
Beds_inhab=df['Beds per 1lakh inhabitants'].mean()
Patients_mean=df['Patients'].mean()
Billing_days=df['Occupancy / billing days'].mean()
Average_stay=df['Average length of stay'].mean()

# %%
Beds
# Out:
# 539594.8064516129

# %%
Beds_inhab
# Out:
# 659.1935483870968

# %%
Patients_mean
# Out:
# 17361418.612903226

# %%
Billing_days
# Out:
# 155131.29032258064

# %%
Average_stay
# Out:
# 8.612903225806452

# %% [markdown]
# ## We can see the mean of the respective values.hence. helping to understand the hospital data better.

# %%
sns.pairplot(df)

# %% [markdown]
# ## With the help of pairplot we are able to check the overall relationship between the data.
